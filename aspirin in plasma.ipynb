# %%
import matplotlib.pyplot as plot
from math import *

simulationlength=16
half_life = 22
aspirin_in_plasma =2*325*1000

plasma_vloume= 3000
r=-log(0.5)/half_life

elimination_constant = -log(0.5)/half_life
timestep=0.01
t=0
numiter=int(simulationlength/timestep)+1

k=r*timestep
pop=[]
tim=[]


for i in range(numiter):
    
    aspirin_in_plasma += k*aspirin_in_plasma

    t=i*timestep

    pop.append(aspirin_in_plasma/plasma_vloume)
    tim.append(t)


plot.plot(tim,pop)
plot.show()



elimination = elimination_constant * aspirin_in_plasma


if t==6 : aspirin_in_plasma =2*325*1000
